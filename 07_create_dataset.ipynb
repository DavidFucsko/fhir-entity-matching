# %%
from data_manipulation import mutate_patients

mutate_patients("input/mixed/train/hospital_A")
mutate_patients("input/mixed/validation/hospital_A")
mutate_patients("input/mixed/test/hospital_A")
# Out:
# c:\Users\fucsk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gecko\mutator.py:781: RuntimeWarning: invalid value encountered in scalar divide
#   p_actual = possible_rows_to_mutate / len(srs)
# c:\Users\fucsk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gecko\mutator.py:837: RuntimeWarning: invalid value encountered in scalar divide
#   p_actual = possible_rows_to_mutate / len(srs)
# c:\Users\fucsk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gecko\mutator.py:904: RuntimeWarning: invalid value encountered in scalar divide
#   p_actual = possible_rows_to_mutate / len(srs)
# c:\Users\fucsk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gecko\mutator.py:837: RuntimeWarning: invalid value encountered in scalar divide
#   p_actual = possible_rows_to_mutate / len(srs)
# c:\Users\fucsk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gecko\mutator.py:781: RuntimeWarning: invalid value encountered in scalar divide
# ...

# %%
from dataset_generator import generate_matching_dataset

generate_matching_dataset(
        "input/mixed/train/hospital_A",
        "input/mixed/train/mutated",
        "output/mixed/train.txt"
    )
generate_matching_dataset(
        "input/mixed/validation/hospital_A",
        "input/mixed/validation/mutated",
        "output/mixed/valid.txt"
    )
generate_matching_dataset(
        "input/mixed/test/hospital_A",
        "input/mixed/test/mutated",
        "output/mixed/test.txt"
    )
# Out:
# Found 60 patients in hospital A
# Found 60 patients in hospital B
# Generating positive examples...
# Generated 60 positive examples
# Generating negative examples...
# Generated 3540 negative examples
# Dataset written to output\mixed\train.txt
# Total examples: 3600 (60 positive, 3540 negative)
# Found 20 patients in hospital A
# Found 20 patients in hospital B
# Generating positive examples...
# Generated 20 positive examples
# Generating negative examples...
# Generated 380 negative examples
# Dataset written to output\mixed\valid.txt
# Total examples: 400 (20 positive, 380 negative)
# Found 20 patients in hospital A
# Found 20 patients in hospital B
# Generating positive examples...
# Generated 20 positive examples
# Generating negative examples...
# Generated 380 negative examples
# Dataset written to output\mixed\test.txt
# Total examples: 400 (20 positive, 380 negative)
